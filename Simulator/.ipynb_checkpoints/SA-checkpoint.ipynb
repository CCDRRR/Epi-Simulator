# %%
pip install mesa==0.8.7
# Out:
# Requirement already satisfied: mesa==0.8.7 in c:\users\47324\anaconda3\lib\site-packages (0.8.7)
# Requirement already satisfied: click in c:\users\47324\anaconda3\lib\site-packages (from mesa==0.8.7) (8.0.4)
# Requirement already satisfied: cookiecutter in c:\users\47324\anaconda3\lib\site-packages (from mesa==0.8.7) (1.7.3)
# Requirement already satisfied: networkx in c:\users\47324\anaconda3\lib\site-packages (from mesa==0.8.7) (3.1)
# Requirement already satisfied: numpy in c:\users\47324\anaconda3\lib\site-packages (from mesa==0.8.7) (1.24.3)
# Requirement already satisfied: pandas in c:\users\47324\anaconda3\lib\site-packages (from mesa==0.8.7) (1.5.3)
# Requirement already satisfied: tornado in c:\users\47324\anaconda3\lib\site-packages (from mesa==0.8.7) (6.3.2)
# Requirement already satisfied: tqdm in c:\users\47324\anaconda3\lib\site-packages (from mesa==0.8.7) (4.65.0)
# Requirement already satisfied: colorama in c:\users\47324\anaconda3\lib\site-packages (from click->mesa==0.8.7) (0.4.6)
# Requirement already satisfied: binaryornot>=0.4.4 in c:\users\47324\anaconda3\lib\site-packages (from cookiecutter->mesa==0.8.7) (0.4.4)
# Requirement already satisfied: Jinja2<4.0.0,>=2.7 in c:\users\47324\anaconda3\lib\site-packages (from cookiecutter->mesa==0.8.7) (3.1.2)
# Requirement already satisfied: poyo>=0.5.0 in c:\users\47324\anaconda3\lib\site-packages (from cookiecutter->mesa==0.8.7) (0.5.0)
# Requirement already satisfied: jinja2-time>=0.2.0 in c:\users\47324\anaconda3\lib\site-packages (from cookiecutter->mesa==0.8.7) (0.2.0)
# Requirement already satisfied: python-slugify>=4.0.0 in c:\users\47324\anaconda3\lib\site-packages (from cookiecutter->mesa==0.8.7) (5.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\47324\anaconda3\lib\site-packages (from cookiecutter->mesa==0.8.7) (2.31.0)
# Requirement already satisfied: six>=1.10 in c:\users\47324\anaconda3\lib\site-packages (from cookiecutter->mesa==0.8.7) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\47324\anaconda3\lib\site-packages (from pandas->mesa==0.8.7) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\47324\anaconda3\lib\site-packages (from pandas->mesa==0.8.7) (2022.7)
# Requirement already satisfied: chardet>=3.0.2 in c:\users\47324\anaconda3\lib\site-packages (from binaryornot>=0.4.4->cookiecutter->mesa==0.8.7) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\47324\anaconda3\lib\site-packages (from Jinja2<4.0.0,>=2.7->cookiecutter->mesa==0.8.7) (2.1.1)
# Requirement already satisfied: arrow in c:\users\47324\anaconda3\lib\site-packages (from jinja2-time>=0.2.0->cookiecutter->mesa==0.8.7) (1.2.3)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\47324\anaconda3\lib\site-packages (from python-slugify>=4.0.0->cookiecutter->mesa==0.8.7) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\47324\anaconda3\lib\site-packages (from requests>=2.23.0->cookiecutter->mesa==0.8.7) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\47324\anaconda3\lib\site-packages (from requests>=2.23.0->cookiecutter->mesa==0.8.7) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\47324\anaconda3\lib\site-packages (from requests>=2.23.0->cookiecutter->mesa==0.8.7) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\47324\anaconda3\lib\site-packages (from requests>=2.23.0->cookiecutter->mesa==0.8.7) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mesa.batchrunner import BatchRunner
from Environment import SIERDModel

class CustomBatchRunner(BatchRunner):
    def run_model(self, model):
        for _ in range(self.max_steps):
            model.step()

# Define variables and bounds
problem = {
    'num_vars': 6,
    'names': ['transmission_rate', 'latency_period', 'infection_duration', 'recovery_rate', 'density', 'initial_infected'],
    'bounds': [[0.1, 1.0], [1, 30], [1, 60], [0.0, 1.0], [0.1, 1.0], [1, 50]]
}

# Set repetitions, steps, and distinct values per variable
replicates = 2
max_steps = 500
distinct_samples = 10

# Default density value
default_density = 0.9

# Calculate total number of agents based on default density
width = 10
height = 10
total_agents = width * height * default_density

# Correcting model_reporters to pass the correct arguments
model_reporters = {
    "Susceptible": lambda m: m.count_state(m, "Susceptible"),
    "Exposed": lambda m: m.count_state(m, "Exposed"),
    "Infected": lambda m: m.count_state(m, "Infected"),
    "Recovered": lambda m: m.count_state(m, "Recovered"),
    "Dead": lambda m: m.count_state(m, "Dead")
}

policies = ["No Interventions", "Mask Policy Only", "Lockdown Only", "Combination of Lockdown and Mask Policy"]
data = {policy: {} for policy in policies}

for policy in policies:
    for i, var in enumerate(problem['names']):
        samples = np.linspace(*problem['bounds'][i], num=distinct_samples)
        
        if var in ['latency_period', 'infection_duration', 'initial_infected']:
            samples = np.linspace(*problem['bounds'][i], num=distinct_samples, dtype=int)
        
        variable_parameters = {var: samples.tolist()}
        fixed_parameters = {
            "width": width,
            "height": height,
            "density": default_density,
            "transmission_rate": 0.6,
            "latency_period": 5,
            "infection_duration": 10,
            "recovery_rate": 0.3,
            "policy": policy,
            "num_districts": 5,
            "initial_infected": 10
        }

        # Ensure the specific variable parameter is updated in fixed_parameters
        del fixed_parameters[var]
        
        batch = CustomBatchRunner(
            SIERDModel,
            max_steps=max_steps,
            iterations=replicates,
            variable_parameters=variable_parameters,
            fixed_parameters=fixed_parameters,
            model_reporters=model_reporters
        )
        
        batch.run_all()
        
        data[policy][var] = batch.get_model_vars_dataframe()

# Plotting function for the current variable
def plot_current_var(df_dict, var, total_agents):
    f, axs = plt.subplots(len(model_reporters), len(df_dict), figsize=(20, 15))
    for i, (param, _) in enumerate(model_reporters.items()):
        for j, (policy, df) in enumerate(df_dict.items()):
            x = df.groupby(var).mean().reset_index()[var]
            y = df.groupby(var).mean()[param]

            replicates = df.groupby(var)[param].count()
            err = (1.96 * df.groupby(var)[param].std()) / np.sqrt(replicates)

            axs[i, j].plot(x, y, c='k')
            axs[i, j].fill_between(x, y - err, y + err, color='gray', alpha=0.2)

            axs[i, j].set_xlabel(var)
            axs[i, j].set_ylabel(param)
            axs[i, j].set_ylim(bottom=-0.1 * total_agents, top=total_agents)  # Ensure y-axis starts just below zero and ends at total agents
            axs[i, j].set_title(f'{param} vs {var} ({policy})')
    
    plt.tight_layout()
    plt.show()

# Plot for each variable
for var in problem['names']:
    df_dict = {policy: data[policy][var] for policy in policies}
    plot_current_var(df_dict, var, total_agents)
# Out:
# 20it [00:06,  3.22it/s]
# 20it [00:07,  2.77it/s]
# 20it [00:06,  3.03it/s]
# 20it [00:06,  3.00it/s]
# 20it [00:03,  5.04it/s]
# 20it [00:06,  3.19it/s]
# 20it [00:07,  2.75it/s]
# 20it [00:07,  2.70it/s]
# 20it [00:06,  3.16it/s]
# 20it [00:08,  2.43it/s]
# 20it [00:03,  5.06it/s]
# 20it [00:07,  2.74it/s]
# 20it [00:10,  1.84it/s]
# 20it [00:11,  1.74it/s]
# 20it [00:10,  1.84it/s]
# 12it [00:06,  1.99it/s]
